# %%
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# '/Documents/hackathon_3.4.20/code_questionnaire/jupyter_notebooks'

# %%
os.chdir('../..')

# %%
os.getcwd()
# Out:
# '/Documents/hackathon_3.4.20'

# %%
os.listdir()
# Out:
# ['.DS_Store',
#  'covid19_temp_latitude_seasonality.pdf',
#  'covid19_sources.docx',
#  'code_questionnaire',
#  'covid19_hightemp_highhumidity.pdf',
#  'questionnaire_data',
#  'covid19_surface_air_stability.pdf']

# %%
os.chdir('questionnaire_data')

# %%
os.listdir()
# Out:
# ['IT-Questionario in Italiano.xlsx',
#  'EN-Questionnaire-ifestyle and contagion.csv',
#  'ES-Questionnaire_espagnol.xlsx',
#  'DE-Questionnaire_allemand.xlsx',
#  'FR-Questionnaire_francais.xlsx',
#  'EN-Questionnaire-ifestyle and contagion.xlsx']

# %%
#data = pd.read_csv('file1.csv', error_bad_lines=False)
en_quest_table = pd.read_csv('EN-Questionnaire-ifestyle and contagion.csv', sep=';', error_bad_lines=False, encoding = "ISO-8859-1")

# %%
en_quest_table.head(15)
# Out:
#             Horodateur  Score  \
# 0   3.27.2020 17:05:36      0
# 1   3.27.2020 17:16:40      0
# 2   3.27.2020 17:16:53      0
# 3   3.27.2020 17:16:58      0
# 4   3.27.2020 17:17:33      0
# 5   3.27.2020 17:18:18      0
# 6   3.27.2020 17:19:25      0
# 7   3.27.2020 17:24:52      0
# 8   3.27.2020 17:28:48      0
# 9   3.27.2020 17:30:35      0
# 10  3.27.2020 17:31:31      0
# 11  3.27.2020 17:38:14      0
# 12  3.27.2020 17:55:44      0
# 13  3.27.2020 18:02:33      0
# 14  3.27.2020 18:18:47      0
#
#    How do you stay informed about the COVID-19 pandemic?   \
# 0   Television, radio, Newspapers or online newspa...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# ...
